# %%
# !git clone https://github.com/MathewAlexander/web_similarity.git
# Out:
# Cloning into 'web_similarity'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 19 (delta 2), reused 17 (delta 2), pack-reused 0
# Unpacking objects: 100% (19/19), done.

# %%
cd web_similarity/
# Out:
# /content/web_similarity

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 71kB 2.0MB/s
# ...
#      |████████████████████████████████| 1.1MB 6.9MB/s
# ...
#      |████████████████████████████████| 3.0MB 15.3MB/s
# ...
#      |████████████████████████████████| 1.1MB 31.1MB/s
# ...
#      |████████████████████████████████| 890kB 44.0MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-0.3.8-cp36-none-any.whl size=101996 sha256=52b75b432c31866d7da262a7e91c2a52db655b236974196f597d2e18a52b3654
#   Stored in directory: /root/.cache/pip/wheels/27/ec/b3/d12cc8e4daf77846db6543033d3a5642f204c0320b15945647
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=21a0a1951b4e8bdfc31bb68faa9cd2276349bc5221548926202f1944ccf2867b
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sentence-transformers sacremoses
# ...

# %%
# !python run.py
# Out:
# 2020-11-08 16:32:00.586076: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 100% 245M/245M [00:13<00:00, 18.7MB/s]
# Paste the first url...https://in.reuters.com/article/health-coronavirus-global-cases/global-coronavirus-cases-exceed-50-million-after-30-day-spike-idINKBN27O0IO?il=0
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
#
#
#
# 		###### Printing the Web content ######
#
# ...
